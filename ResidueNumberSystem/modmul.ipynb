# %%
def mod_mul_standard(a, b, p):
    result = (a * b) % p
    if result > (p>>1):
        result -= p
    return result

# %%
def Mu(b,q):
    mu = 2*int(((b << 31)/(2*q))+0.5)
    return mu

# %%
def Barrett_mul(a, b, p, mu_b):
    # Perform the multiplication
    z = (a * b) % (1 << 32)
    if z >= (1 << 31):
        z -= (1 << 32)  # Convert to signed 32-bit integer

    # Perform the multiplication for mu_b and get the high 32 bits
    temp = (a * (mu_b << 1)) % (1 << 64)
    t_high = (temp >> 32) % (1 << 32)
    if t_high >= (1 << 31):
        t_high -= (1 << 32)  # Convert to signed 32-bit integer
    
    result = z - t_high * p
    # Simulate 32-bit signed integer overflow for the result
    result %= (1 << 32)
    if result >= (1 << 31):
        result -= (1 << 32)  # Convert to signed 32-bit integer

    return result

# %%
a = 312222
b = 213222
p = 33550337
mu_b = Mu(b,p)
print(mu_b)

print(Barrett_mul(a,b,p,mu_b))
print(mod_mul_standard(a,b,p))
# Out:
# 13647874
# 8730676
# 8730676

# %%
# %%writefile Barrett_mul.c
#
# #include <stdio.h>
# #include <stdint.h>
# #include <stdlib.h> // 提供 atoi 函數
#
# // Barrett Reduction Multiplication
# int32_t Barrett_mul(int32_t a, int32_t b, int32_t mod, int32_t mu_b) {
#     int32_t z = a * b;
#     int32_t t_high = (int32_t)(((int64_t)a * (int64_t)(mu_b << 1)) >> 32);
#     return (z - t_high * mod);
# }
#
# int main(int argc, char *argv[]) {
#     if (argc != 5) { // 檢查參數數量
#         printf("Usage: ./Barrett_mul <a> <b> <mod> <mu_b>\n");
#         return 1; // 錯誤返回值
#     }
#
#     // 將命令列參數轉為整數
#     int32_t a = atoi(argv[1]);
#     int32_t b = atoi(argv[2]);
#     int32_t mod = atoi(argv[3]);
#     int32_t mu_b = atoi(argv[4]);
#
#     // 計算結果
#     int32_t result = Barrett_mul(a, b, mod, mu_b);
#     printf("Result: %d\n", result);
#
#     return 0;
# }
# Out:
# Overwriting Barrett_mul.c

# %%
# !gcc -o Barrett_mul Barrett_mul.c

# %%
import subprocess

# 定義參數
a = 312222
b = 213222
mod = 33550337
mu_b = 13647874

# 執行 C 程式
process = subprocess.run(
    ["./Barrett_mul", str(a), str(b), str(mod), str(mu_b)],
    capture_output=True,
    text=True
)

# 處理輸出
if process.returncode == 0:
    # 擷取並轉換輸出結果
    result = int(process.stdout.split(":")[1].strip())
    print(f"Captured Result: {result}")
else:
    print("Error:", process.stderr)
# Out:
# Captured Result: 8730676

# %%
result == Barrett_mul(a,b,p,mu_b)
# Out:
# True

# %%
# correctness test

import subprocess

# 固定的模數
p = 33550337



# 遍歷 b
for b in range(-p // 2, p // 2 + 1):
    mu_b = Mu(b, p)  # 計算對應的 mu 值

    # 遍歷 a
    for a in range(-p // 2, p // 2 + 1):
        # 執行 C 程式
        process = subprocess.run(
            ["./Barrett_mul", str(a), str(b), str(p), str(mu_b)],
            capture_output=True,
            text=True
        )

        # 確保執行成功
        if process.returncode != 0:
            print(f"Error for a={a}, b={b}, mu_b={mu_b}: {process.stderr}")
            continue

        # 獲取結果
        c_result = int(process.stdout.split(":")[1].strip())  # C 程式輸出的結果
        python_result = mod_mul_standard(a, b, p)  # Python 標準結果

        # 驗證
        if c_result != python_result:
            print(f"Discrepancy found: a={a}, b={b}, C_result={c_result}, Python_result={python_result}")
# Out:
# Discrepancy found: a=-16775169, b=-16775169, C_result=83876866, Python_result=-8387584
# Discrepancy found: a=-16775168, b=-16775169, C_result=33551360, Python_result=8387584
# Discrepancy found: a=-16775167, b=-16775169, C_result=16776191, Python_result=-8387585
# Discrepancy found: a=-16775166, b=-16775169, C_result=-33549315, Python_result=8387583
# Discrepancy found: a=-16775165, b=-16775169, C_result=-50324484, Python_result=-8387586
# Discrepancy found: a=-16775164, b=-16775169, C_result=-100649990, Python_result=8387582
# Discrepancy found: a=-16775163, b=-16775169, C_result=-117425159, Python_result=-8387587
# Discrepancy found: a=-16775162, b=-16775169, C_result=-167750665, Python_result=8387581
# Discrepancy found: a=-16775161, b=-16775169, C_result=-184525834, Python_result=-8387588
# Discrepancy found: a=-16775160, b=-16775169, C_result=-234851340, Python_result=8387580
# Discrepancy found: a=-16775159, b=-16775169, C_result=-251626509, Python_result=-8387589
# Discrepancy found: a=-16775158, b=-16775169, C_result=-301952015, Python_result=8387579
# Discrepancy found: a=-16775157, b=-16775169, C_result=-318727184, Python_result=-8387590
# Discrepancy found: a=-16775156, b=-16775169, C_result=-369052690, Python_result=8387578
# Discrepancy found: a=-16775155, b=-16775169, C_result=-385827859, Python_result=-8387591
# Discrepancy found: a=-16775154, b=-16775169, C_result=-436153365, Python_result=8387577
# Discrepancy found: a=-16775153, b=-16775169, C_result=-452928534, Python_result=-8387592
# Discrepancy found: a=-16775152, b=-16775169, C_result=-503254040, Python_result=8387576
# Discrepancy found: a=-16775151, b=-16775169, C_result=-520029209, Python_result=-8387593
# Discrepancy found: a=-16775150, b=-16775169, C_result=-570354715, Python_result=8387575
# Discrepancy found: a=-16775149, b=-16775169, C_result=-587129884, Python_result=-8387594
# Discrepancy found: a=-16775148, b=-16775169, C_result=-637455390, Python_result=8387574
# Discrepancy found: a=-16775147, b=-16775169, C_result=-654230559, Python_result=-8387595
# Discrepancy found: a=-16775146, b=-16775169, C_result=-704556065, Python_result=8387573
# Discrepancy found: a=-16775145, b=-16775169, C_result=-721331234, Python_result=-8387596
# Discrepancy found: a=-16775144, b=-16775169, C_result=-771656740, Python_result=8387572
# Discrepancy found: a=-16775143, b=-16775169, C_result=-788431909, Python_result=-8387597
# Discrepancy found: a=-16775142, b=-16775169, C_result=-838757415, Python_result=8387571
# Discrepancy found: a=-16775141, b=-16775169, C_result=-855532584, Python_result=-8387598
# Discrepancy found: a=-16775140, b=-16775169, C_result=-905858090, Python_result=8387570
# Discrepancy found: a=-16775139, b=-16775169, C_result=-922633259, Python_result=-8387599
# Discrepancy found: a=-16775138, b=-16775169, C_result=-972958765, Python_result=8387569
# Discrepancy found: a=-16775137, b=-16775169, C_result=-989733934, Python_result=-8387600
# Discrepancy found: a=-16775136, b=-16775169, C_result=-1040059440, Python_result=8387568
# Discrepancy found: a=-16775135, b=-16775169, C_result=-1056834609, Python_result=-8387601
# Discrepancy found: a=-16775134, b=-16775169, C_result=-1107160115, Python_result=8387567
# Discrepancy found: a=-16775133, b=-16775169, C_result=-1123935284, Python_result=-8387602
# Discrepancy found: a=-16775132, b=-16775169, C_result=-1174260790, Python_result=8387566
# Discrepancy found: a=-16775131, b=-16775169, C_result=-1191035959, Python_result=-8387603
# Discrepancy found: a=-16775130, b=-16775169, C_result=-1241361465, Python_result=8387565
# Discrepancy found: a=-16775129, b=-16775169, C_result=-1258136634, Python_result=-8387604
# Discrepancy found: a=-16775128, b=-16775169, C_result=-1308462140, Python_result=8387564
# Discrepancy found: a=-16775127, b=-16775169, C_result=-1325237309, Python_result=-8387605
# Discrepancy found: a=-16775126, b=-16775169, C_result=-1375562815, Python_result=8387563
# Discrepancy found: a=-16775125, b=-16775169, C_result=-1392337984, Python_result=-8387606
# Discrepancy found: a=-16775124, b=-16775169, C_result=-1442663490, Python_result=8387562
# Discrepancy found: a=-16775123, b=-16775169, C_result=-1459438659, Python_result=-8387607
# Discrepancy found: a=-16775122, b=-16775169, C_result=-1509764165, Python_result=8387561
# Discrepancy found: a=-16775121, b=-16775169, C_result=-1526539334, Python_result=-8387608
# Discrepancy found: a=-16775120, b=-16775169, C_result=-1576864840, Python_result=8387560
# Discrepancy found: a=-16775119, b=-16775169, C_result=-1593640009, Python_result=-8387609
# Discrepancy found: a=-16775118, b=-16775169, C_result=-1643965515, Python_result=8387559
# Discrepancy found: a=-16775117, b=-16775169, C_result=-1660740684, Python_result=-8387610
# Discrepancy found: a=-16775116, b=-16775169, C_result=-1711066190, Python_result=8387558
# Discrepancy found: a=-16775115, b=-16775169, C_result=-1727841359, Python_result=-8387611
# Discrepancy found: a=-16775114, b=-16775169, C_result=-1778166865, Python_result=8387557
# Discrepancy found: a=-16775113, b=-16775169, C_result=-1794942034, Python_result=-8387612
# Discrepancy found: a=-16775112, b=-16775169, C_result=-1845267540, Python_result=8387556
# Discrepancy found: a=-16775111, b=-16775169, C_result=-1862042709, Python_result=-8387613
# Discrepancy found: a=-16775110, b=-16775169, C_result=-1912368215, Python_result=8387555
# Discrepancy found: a=-16775109, b=-16775169, C_result=-1929143384, Python_result=-8387614
# Discrepancy found: a=-16775108, b=-16775169, C_result=-1979468890, Python_result=8387554
# Discrepancy found: a=-16775107, b=-16775169, C_result=-1996244059, Python_result=-8387615
# Discrepancy found: a=-16775106, b=-16775169, C_result=-2046569565, Python_result=8387553
# Discrepancy found: a=-16775105, b=-16775169, C_result=-2063344734, Python_result=-8387616
# Discrepancy found: a=-16775104, b=-16775169, C_result=-2113670240, Python_result=8387552
# Discrepancy found: a=-16775103, b=-16775169, C_result=-2130445409, Python_result=-8387617
# Discrepancy found: a=-16775102, b=-16775169, C_result=2114196381, Python_result=8387551
# Discrepancy found: a=-16775101, b=-16775169, C_result=2097421212, Python_result=-8387618
# Discrepancy found: a=-16775100, b=-16775169, C_result=2047095706, Python_result=8387550
# Discrepancy found: a=-16775099, b=-16775169, C_result=2030320537, Python_result=-8387619
# Discrepancy found: a=-16775098, b=-16775169, C_result=1979995031, Python_result=8387549
# Discrepancy found: a=-16775097, b=-16775169, C_result=1963219862, Python_result=-8387620
# Discrepancy found: a=-16775096, b=-16775169, C_result=1912894356, Python_result=8387548
# Discrepancy found: a=-16775095, b=-16775169, C_result=1896119187, Python_result=-8387621
# Discrepancy found: a=-16775094, b=-16775169, C_result=1845793681, Python_result=8387547
# Discrepancy found: a=-16775093, b=-16775169, C_result=1829018512, Python_result=-8387622
# Discrepancy found: a=-16775092, b=-16775169, C_result=1778693006, Python_result=8387546
# Discrepancy found: a=-16775091, b=-16775169, C_result=1761917837, Python_result=-8387623
# Discrepancy found: a=-16775090, b=-16775169, C_result=1711592331, Python_result=8387545
# Discrepancy found: a=-16775089, b=-16775169, C_result=1694817162, Python_result=-8387624
# Discrepancy found: a=-16775088, b=-16775169, C_result=1644491656, Python_result=8387544
# Discrepancy found: a=-16775087, b=-16775169, C_result=1627716487, Python_result=-8387625
# Discrepancy found: a=-16775086, b=-16775169, C_result=1577390981, Python_result=8387543
# Discrepancy found: a=-16775085, b=-16775169, C_result=1560615812, Python_result=-8387626
# Discrepancy found: a=-16775084, b=-16775169, C_result=1510290306, Python_result=8387542
# Discrepancy found: a=-16775083, b=-16775169, C_result=1493515137, Python_result=-8387627
# Discrepancy found: a=-16775082, b=-16775169, C_result=1443189631, Python_result=8387541
# Discrepancy found: a=-16775081, b=-16775169, C_result=1426414462, Python_result=-8387628
# Discrepancy found: a=-16775080, b=-16775169, C_result=1376088956, Python_result=8387540
# Discrepancy found: a=-16775079, b=-16775169, C_result=1359313787, Python_result=-8387629
# Discrepancy found: a=-16775078, b=-16775169, C_result=1308988281, Python_result=8387539
# Discrepancy found: a=-16775077, b=-16775169, C_result=1292213112, Python_result=-8387630
# Discrepancy found: a=-16775076, b=-16775169, C_result=1241887606, Python_result=8387538
# Discrepancy found: a=-16775075, b=-16775169, C_result=1225112437, Python_result=-8387631
# Discrepancy found: a=-16775074, b=-16775169, C_result=1174786931, Python_result=8387537
# Discrepancy found: a=-16775073, b=-16775169, C_result=1158011762, Python_result=-8387632
# Discrepancy found: a=-16775072, b=-16775169, C_result=1107686256, Python_result=8387536
# Discrepancy found: a=-16775071, b=-16775169, C_result=1090911087, Python_result=-8387633
# Discrepancy found: a=-16775070, b=-16775169, C_result=1040585581, Python_result=8387535
# Discrepancy found: a=-16775069, b=-16775169, C_result=1023810412, Python_result=-8387634
# Discrepancy found: a=-16775068, b=-16775169, C_result=973484906, Python_result=8387534
# Discrepancy found: a=-16775067, b=-16775169, C_result=956709737, Python_result=-8387635
# Discrepancy found: a=-16775066, b=-16775169, C_result=906384231, Python_result=8387533
# Discrepancy found: a=-16775065, b=-16775169, C_result=889609062, Python_result=-8387636
# Discrepancy found: a=-16775064, b=-16775169, C_result=839283556, Python_result=8387532
# Discrepancy found: a=-16775063, b=-16775169, C_result=822508387, Python_result=-8387637
# Discrepancy found: a=-16775062, b=-16775169, C_result=772182881, Python_result=8387531
# Discrepancy found: a=-16775061, b=-16775169, C_result=755407712, Python_result=-8387638
# Discrepancy found: a=-16775060, b=-16775169, C_result=705082206, Python_result=8387530
# Discrepancy found: a=-16775059, b=-16775169, C_result=688307037, Python_result=-8387639
# Discrepancy found: a=-16775058, b=-16775169, C_result=637981531, Python_result=8387529
# Discrepancy found: a=-16775057, b=-16775169, C_result=621206362, Python_result=-8387640
# Discrepancy found: a=-16775056, b=-16775169, C_result=570880856, Python_result=8387528
# Discrepancy found: a=-16775055, b=-16775169, C_result=554105687, Python_result=-8387641
# Discrepancy found: a=-16775054, b=-16775169, C_result=503780181, Python_result=8387527
# Discrepancy found: a=-16775053, b=-16775169, C_result=487005012, Python_result=-8387642
# Discrepancy found: a=-16775052, b=-16775169, C_result=436679506, Python_result=8387526
# Discrepancy found: a=-16775051, b=-16775169, C_result=419904337, Python_result=-8387643
# Discrepancy found: a=-16775050, b=-16775169, C_result=369578831, Python_result=8387525
# Discrepancy found: a=-16775049, b=-16775169, C_result=352803662, Python_result=-8387644
# Discrepancy found: a=-16775048, b=-16775169, C_result=302478156, Python_result=8387524
# Discrepancy found: a=-16775047, b=-16775169, C_result=285702987, Python_result=-8387645
# Discrepancy found: a=-16775046, b=-16775169, C_result=235377481, Python_result=8387523
# Discrepancy found: a=-16775045, b=-16775169, C_result=218602312, Python_result=-8387646
# Discrepancy found: a=-16775044, b=-16775169, C_result=168276806, Python_result=8387522
# Discrepancy found: a=-16775043, b=-16775169, C_result=151501637, Python_result=-8387647
# Discrepancy found: a=-16775042, b=-16775169, C_result=101176131, Python_result=8387521
# Discrepancy found: a=-16775041, b=-16775169, C_result=84400962, Python_result=-8387648
# Discrepancy found: a=-16775040, b=-16775169, C_result=34075456, Python_result=8387520
# Discrepancy found: a=-16775039, b=-16775169, C_result=17300287, Python_result=-8387649
# Discrepancy found: a=-16775038, b=-16775169, C_result=-33025219, Python_result=8387519
# Discrepancy found: a=-16775037, b=-16775169, C_result=-49800388, Python_result=-8387650
# Discrepancy found: a=-16775036, b=-16775169, C_result=-100125894, Python_result=8387518
# Discrepancy found: a=-16775035, b=-16775169, C_result=-116901063, Python_result=-8387651
# Discrepancy found: a=-16775034, b=-16775169, C_result=-167226569, Python_result=8387517
# Discrepancy found: a=-16775033, b=-16775169, C_result=-184001738, Python_result=-8387652
# Discrepancy found: a=-16775032, b=-16775169, C_result=-234327244, Python_result=8387516
# Discrepancy found: a=-16775031, b=-16775169, C_result=-251102413, Python_result=-8387653
# Discrepancy found: a=-16775030, b=-16775169, C_result=-301427919, Python_result=8387515
# Discrepancy found: a=-16775029, b=-16775169, C_result=-318203088, Python_result=-8387654
# Discrepancy found: a=-16775028, b=-16775169, C_result=-368528594, Python_result=8387514
# Discrepancy found: a=-16775027, b=-16775169, C_result=-385303763, Python_result=-8387655
# Discrepancy found: a=-16775026, b=-16775169, C_result=-435629269, Python_result=8387513
# Discrepancy found: a=-16775025, b=-16775169, C_result=-452404438, Python_result=-8387656
# Discrepancy found: a=-16775024, b=-16775169, C_result=-502729944, Python_result=8387512
# Discrepancy found: a=-16775023, b=-16775169, C_result=-519505113, Python_result=-8387657
# Discrepancy found: a=-16775022, b=-16775169, C_result=-569830619, Python_result=8387511
# Discrepancy found: a=-16775021, b=-16775169, C_result=-586605788, Python_result=-8387658
# Discrepancy found: a=-16775020, b=-16775169, C_result=-636931294, Python_result=8387510
# Discrepancy found: a=-16775019, b=-16775169, C_result=-653706463, Python_result=-8387659
# Discrepancy found: a=-16775018, b=-16775169, C_result=-704031969, Python_result=8387509
# Discrepancy found: a=-16775017, b=-16775169, C_result=-720807138, Python_result=-8387660
# Discrepancy found: a=-16775016, b=-16775169, C_result=-771132644, Python_result=8387508
# Discrepancy found: a=-16775015, b=-16775169, C_result=-787907813, Python_result=-8387661
# Discrepancy found: a=-16775014, b=-16775169, C_result=-838233319, Python_result=8387507
# Discrepancy found: a=-16775013, b=-16775169, C_result=-855008488, Python_result=-8387662
# Discrepancy found: a=-16775012, b=-16775169, C_result=-905333994, Python_result=8387506
# Discrepancy found: a=-16775011, b=-16775169, C_result=-922109163, Python_result=-8387663
# Discrepancy found: a=-16775010, b=-16775169, C_result=-972434669, Python_result=8387505
# Discrepancy found: a=-16775009, b=-16775169, C_result=-989209838, Python_result=-8387664
# Discrepancy found: a=-16775008, b=-16775169, C_result=-1039535344, Python_result=8387504
# Discrepancy found: a=-16775007, b=-16775169, C_result=-1056310513, Python_result=-8387665
# Discrepancy found: a=-16775006, b=-16775169, C_result=-1106636019, Python_result=8387503
# Discrepancy found: a=-16775005, b=-16775169, C_result=-1123411188, Python_result=-8387666
# Discrepancy found: a=-16775004, b=-16775169, C_result=-1173736694, Python_result=8387502
# Discrepancy found: a=-16775003, b=-16775169, C_result=-1190511863, Python_result=-8387667
# Discrepancy found: a=-16775002, b=-16775169, C_result=-1240837369, Python_result=8387501
# Discrepancy found: a=-16775001, b=-16775169, C_result=-1257612538, Python_result=-8387668
# Discrepancy found: a=-16775000, b=-16775169, C_result=-1307938044, Python_result=8387500
# Discrepancy found: a=-16774999, b=-16775169, C_result=-1324713213, Python_result=-8387669
# Discrepancy found: a=-16774998, b=-16775169, C_result=-1375038719, Python_result=8387499
# Discrepancy found: a=-16774997, b=-16775169, C_result=-1391813888, Python_result=-8387670
# Discrepancy found: a=-16774996, b=-16775169, C_result=-1442139394, Python_result=8387498
# Discrepancy found: a=-16774995, b=-16775169, C_result=-1458914563, Python_result=-8387671
# Discrepancy found: a=-16774994, b=-16775169, C_result=-1509240069, Python_result=8387497
# Discrepancy found: a=-16774993, b=-16775169, C_result=-1526015238, Python_result=-8387672
# Discrepancy found: a=-16774992, b=-16775169, C_result=-1576340744, Python_result=8387496
# Discrepancy found: a=-16774991, b=-16775169, C_result=-1593115913, Python_result=-8387673
# Discrepancy found: a=-16774990, b=-16775169, C_result=-1643441419, Python_result=8387495
# Discrepancy found: a=-16774989, b=-16775169, C_result=-1660216588, Python_result=-8387674
# Discrepancy found: a=-16774988, b=-16775169, C_result=-1710542094, Python_result=8387494
# Discrepancy found: a=-16774987, b=-16775169, C_result=-1727317263, Python_result=-8387675
# Discrepancy found: a=-16774986, b=-16775169, C_result=-1777642769, Python_result=8387493
# Discrepancy found: a=-16774985, b=-16775169, C_result=-1794417938, Python_result=-8387676
# Discrepancy found: a=-16774984, b=-16775169, C_result=-1844743444, Python_result=8387492
# Discrepancy found: a=-16774983, b=-16775169, C_result=-1861518613, Python_result=-8387677
# Discrepancy found: a=-16774982, b=-16775169, C_result=-1911844119, Python_result=8387491
# Discrepancy found: a=-16774981, b=-16775169, C_result=-1928619288, Python_result=-8387678
# Discrepancy found: a=-16774980, b=-16775169, C_result=-1978944794, Python_result=8387490
# Discrepancy found: a=-16774979, b=-16775169, C_result=-1995719963, Python_result=-8387679
# Discrepancy found: a=-16774978, b=-16775169, C_result=-2046045469, Python_result=8387489
# Discrepancy found: a=-16774977, b=-16775169, C_result=-2062820638, Python_result=-8387680
# Discrepancy found: a=-16774976, b=-16775169, C_result=-2113146144, Python_result=8387488
# Discrepancy found: a=-16774975, b=-16775169, C_result=-2129921313, Python_result=-8387681
# Discrepancy found: a=-16774974, b=-16775169, C_result=2114720477, Python_result=8387487
# Discrepancy found: a=-16774973, b=-16775169, C_result=2097945308, Python_result=-8387682
# Discrepancy found: a=-16774972, b=-16775169, C_result=2047619802, Python_result=8387486
# Discrepancy found: a=-16774971, b=-16775169, C_result=2030844633, Python_result=-8387683
# Discrepancy found: a=-16774970, b=-16775169, C_result=1980519127, Python_result=8387485
# Discrepancy found: a=-16774969, b=-16775169, C_result=1963743958, Python_result=-8387684
# Discrepancy found: a=-16774968, b=-16775169, C_result=1913418452, Python_result=8387484
# Discrepancy found: a=-16774967, b=-16775169, C_result=1896643283, Python_result=-8387685
# Discrepancy found: a=-16774966, b=-16775169, C_result=1846317777, Python_result=8387483
# Discrepancy found: a=-16774965, b=-16775169, C_result=1829542608, Python_result=-8387686
# Discrepancy found: a=-16774964, b=-16775169, C_result=1779217102, Python_result=8387482
# Discrepancy found: a=-16774963, b=-16775169, C_result=1762441933, Python_result=-8387687
# Discrepancy found: a=-16774962, b=-16775169, C_result=1712116427, Python_result=8387481
# Discrepancy found: a=-16774961, b=-16775169, C_result=1695341258, Python_result=-8387688
# Discrepancy found: a=-16774960, b=-16775169, C_result=1645015752, Python_result=8387480
# Discrepancy found: a=-16774959, b=-16775169, C_result=1628240583, Python_result=-8387689
# Discrepancy found: a=-16774958, b=-16775169, C_result=1577915077, Python_result=8387479
# Discrepancy found: a=-16774957, b=-16775169, C_result=1561139908, Python_result=-8387690
# Discrepancy found: a=-16774956, b=-16775169, C_result=1510814402, Python_result=8387478
# Discrepancy found: a=-16774955, b=-16775169, C_result=1494039233, Python_result=-8387691
# Discrepancy found: a=-16774954, b=-16775169, C_result=1443713727, Python_result=8387477
# Discrepancy found: a=-16774953, b=-16775169, C_result=1426938558, Python_result=-8387692
# Discrepancy found: a=-16774952, b=-16775169, C_result=1376613052, Python_result=8387476
# Discrepancy found: a=-16774951, b=-16775169, C_result=1359837883, Python_result=-8387693
# Discrepancy found: a=-16774950, b=-16775169, C_result=1309512377, Python_result=8387475
# Discrepancy found: a=-16774949, b=-16775169, C_result=1292737208, Python_result=-8387694
# Discrepancy found: a=-16774948, b=-16775169, C_result=1242411702, Python_result=8387474
# Discrepancy found: a=-16774947, b=-16775169, C_result=1225636533, Python_result=-8387695
# Discrepancy found: a=-16774946, b=-16775169, C_result=1175311027, Python_result=8387473
# Discrepancy found: a=-16774945, b=-16775169, C_result=1158535858, Python_result=-8387696
# Discrepancy found: a=-16774944, b=-16775169, C_result=1108210352, Python_result=8387472
# Discrepancy found: a=-16774943, b=-16775169, C_result=1091435183, Python_result=-8387697
# Discrepancy found: a=-16774942, b=-16775169, C_result=1041109677, Python_result=8387471
# Discrepancy found: a=-16774941, b=-16775169, C_result=1024334508, Python_result=-8387698
# Discrepancy found: a=-16774940, b=-16775169, C_result=974009002, Python_result=8387470
# Discrepancy found: a=-16774939, b=-16775169, C_result=957233833, Python_result=-8387699
# Discrepancy found: a=-16774938, b=-16775169, C_result=906908327, Python_result=8387469
# Discrepancy found: a=-16774937, b=-16775169, C_result=890133158, Python_result=-8387700
# Discrepancy found: a=-16774936, b=-16775169, C_result=839807652, Python_result=8387468
# Discrepancy found: a=-16774935, b=-16775169, C_result=823032483, Python_result=-8387701
# Discrepancy found: a=-16774934, b=-16775169, C_result=772706977, Python_result=8387467
# Discrepancy found: a=-16774933, b=-16775169, C_result=755931808, Python_result=-8387702
# Discrepancy found: a=-16774932, b=-16775169, C_result=705606302, Python_result=8387466
# Discrepancy found: a=-16774931, b=-16775169, C_result=688831133, Python_result=-8387703
# Discrepancy found: a=-16774930, b=-16775169, C_result=638505627, Python_result=8387465
# Discrepancy found: a=-16774929, b=-16775169, C_result=621730458, Python_result=-8387704
# Discrepancy found: a=-16774928, b=-16775169, C_result=571404952, Python_result=8387464
# Discrepancy found: a=-16774927, b=-16775169, C_result=554629783, Python_result=-8387705
# Discrepancy found: a=-16774926, b=-16775169, C_result=504304277, Python_result=8387463
# Discrepancy found: a=-16774925, b=-16775169, C_result=487529108, Python_result=-8387706
# Discrepancy found: a=-16774924, b=-16775169, C_result=437203602, Python_result=8387462
# Discrepancy found: a=-16774923, b=-16775169, C_result=420428433, Python_result=-8387707
# Discrepancy found: a=-16774922, b=-16775169, C_result=370102927, Python_result=8387461
# Discrepancy found: a=-16774921, b=-16775169, C_result=353327758, Python_result=-8387708
# Discrepancy found: a=-16774920, b=-16775169, C_result=303002252, Python_result=8387460
# Discrepancy found: a=-16774919, b=-16775169, C_result=286227083, Python_result=-8387709
# Discrepancy found: a=-16774918, b=-16775169, C_result=235901577, Python_result=8387459
# Discrepancy found: a=-16774917, b=-16775169, C_result=219126408, Python_result=-8387710
# Discrepancy found: a=-16774916, b=-16775169, C_result=168800902, Python_result=8387458
# Discrepancy found: a=-16774915, b=-16775169, C_result=152025733, Python_result=-8387711
# Discrepancy found: a=-16774914, b=-16775169, C_result=101700227, Python_result=8387457
# Discrepancy found: a=-16774913, b=-16775169, C_result=84925058, Python_result=-8387712
# Discrepancy found: a=-16774912, b=-16775169, C_result=34599552, Python_result=8387456
# Discrepancy found: a=-16774911, b=-16775169, C_result=17824383, Python_result=-8387713
# Discrepancy found: a=-16774910, b=-16775169, C_result=-32501123, Python_result=8387455
# Discrepancy found: a=-16774909, b=-16775169, C_result=-49276292, Python_result=-8387714
# Discrepancy found: a=-16774908, b=-16775169, C_result=-99601798, Python_result=8387454
# Discrepancy found: a=-16774907, b=-16775169, C_result=-116376967, Python_result=-8387715
# Discrepancy found: a=-16774906, b=-16775169, C_result=-166702473, Python_result=8387453
# Discrepancy found: a=-16774905, b=-16775169, C_result=-183477642, Python_result=-8387716
# Discrepancy found: a=-16774904, b=-16775169, C_result=-233803148, Python_result=8387452
# Discrepancy found: a=-16774903, b=-16775169, C_result=-250578317, Python_result=-8387717
# Discrepancy found: a=-16774902, b=-16775169, C_result=-300903823, Python_result=8387451
# Discrepancy found: a=-16774901, b=-16775169, C_result=-317678992, Python_result=-8387718
# Discrepancy found: a=-16774900, b=-16775169, C_result=-368004498, Python_result=8387450
# Discrepancy found: a=-16774899, b=-16775169, C_result=-384779667, Python_result=-8387719
# Discrepancy found: a=-16774898, b=-16775169, C_result=-435105173, Python_result=8387449
# Discrepancy found: a=-16774897, b=-16775169, C_result=-451880342, Python_result=-8387720
# Discrepancy found: a=-16774896, b=-16775169, C_result=-502205848, Python_result=8387448
# Discrepancy found: a=-16774895, b=-16775169, C_result=-518981017, Python_result=-8387721
# Discrepancy found: a=-16774894, b=-16775169, C_result=-569306523, Python_result=8387447
# Discrepancy found: a=-16774893, b=-16775169, C_result=-586081692, Python_result=-8387722
# Discrepancy found: a=-16774892, b=-16775169, C_result=-636407198, Python_result=8387446
# Discrepancy found: a=-16774891, b=-16775169, C_result=-653182367, Python_result=-8387723
# Discrepancy found: a=-16774890, b=-16775169, C_result=-703507873, Python_result=8387445
# Discrepancy found: a=-16774889, b=-16775169, C_result=-720283042, Python_result=-8387724
# Discrepancy found: a=-16774888, b=-16775169, C_result=-770608548, Python_result=8387444
# Discrepancy found: a=-16774887, b=-16775169, C_result=-787383717, Python_result=-8387725
# Discrepancy found: a=-16774886, b=-16775169, C_result=-837709223, Python_result=8387443
# Discrepancy found: a=-16774885, b=-16775169, C_result=-854484392, Python_result=-8387726
# Discrepancy found: a=-16774884, b=-16775169, C_result=-904809898, Python_result=8387442
# Discrepancy found: a=-16774883, b=-16775169, C_result=-921585067, Python_result=-8387727
# Discrepancy found: a=-16774882, b=-16775169, C_result=-971910573, Python_result=8387441
# Discrepancy found: a=-16774881, b=-16775169, C_result=-988685742, Python_result=-8387728
# Discrepancy found: a=-16774880, b=-16775169, C_result=-1039011248, Python_result=8387440
# Discrepancy found: a=-16774879, b=-16775169, C_result=-1055786417, Python_result=-8387729
# Discrepancy found: a=-16774878, b=-16775169, C_result=-1106111923, Python_result=8387439
# Discrepancy found: a=-16774877, b=-16775169, C_result=-1122887092, Python_result=-8387730
# Discrepancy found: a=-16774876, b=-16775169, C_result=-1173212598, Python_result=8387438
# Discrepancy found: a=-16774875, b=-16775169, C_result=-1189987767, Python_result=-8387731
# Discrepancy found: a=-16774874, b=-16775169, C_result=-1240313273, Python_result=8387437
# Discrepancy found: a=-16774873, b=-16775169, C_result=-1257088442, Python_result=-8387732
# Discrepancy found: a=-16774872, b=-16775169, C_result=-1307413948, Python_result=8387436
# Discrepancy found: a=-16774871, b=-16775169, C_result=-1324189117, Python_result=-8387733
# Discrepancy found: a=-16774870, b=-16775169, C_result=-1374514623, Python_result=8387435
# Discrepancy found: a=-16774869, b=-16775169, C_result=-1391289792, Python_result=-8387734
# Discrepancy found: a=-16774868, b=-16775169, C_result=-1441615298, Python_result=8387434
# Discrepancy found: a=-16774867, b=-16775169, C_result=-1458390467, Python_result=-8387735
# Discrepancy found: a=-16774866, b=-16775169, C_result=-1508715973, Python_result=8387433
# Discrepancy found: a=-16774865, b=-16775169, C_result=-1525491142, Python_result=-8387736
# Discrepancy found: a=-16774864, b=-16775169, C_result=-1575816648, Python_result=8387432
# Discrepancy found: a=-16774863, b=-16775169, C_result=-1592591817, Python_result=-8387737
# Discrepancy found: a=-16774862, b=-16775169, C_result=-1642917323, Python_result=8387431
# Discrepancy found: a=-16774861, b=-16775169, C_result=-1659692492, Python_result=-8387738
# Discrepancy found: a=-16774860, b=-16775169, C_result=-1710017998, Python_result=8387430
# Discrepancy found: a=-16774859, b=-16775169, C_result=-1726793167, Python_result=-8387739
# Discrepancy found: a=-16774858, b=-16775169, C_result=-1777118673, Python_result=8387429
# Discrepancy found: a=-16774857, b=-16775169, C_result=-1793893842, Python_result=-8387740
# Discrepancy found: a=-16774856, b=-16775169, C_result=-1844219348, Python_result=8387428
# Discrepancy found: a=-16774855, b=-16775169, C_result=-1860994517, Python_result=-8387741
# Discrepancy found: a=-16774854, b=-16775169, C_result=-1911320023, Python_result=8387427
# Discrepancy found: a=-16774853, b=-16775169, C_result=-1928095192, Python_result=-8387742
# Discrepancy found: a=-16774852, b=-16775169, C_result=-1978420698, Python_result=8387426
# Discrepancy found: a=-16774851, b=-16775169, C_result=-1995195867, Python_result=-8387743
# Discrepancy found: a=-16774850, b=-16775169, C_result=-2045521373, Python_result=8387425
# Discrepancy found: a=-16774849, b=-16775169, C_result=-2062296542, Python_result=-8387744
# Discrepancy found: a=-16774848, b=-16775169, C_result=-2112622048, Python_result=8387424
# Discrepancy found: a=-16774847, b=-16775169, C_result=-2129397217, Python_result=-8387745
# Discrepancy found: a=-16774846, b=-16775169, C_result=2115244573, Python_result=8387423
# Discrepancy found: a=-16774845, b=-16775169, C_result=2098469404, Python_result=-8387746
# Discrepancy found: a=-16774844, b=-16775169, C_result=2048143898, Python_result=8387422
# Discrepancy found: a=-16774843, b=-16775169, C_result=2031368729, Python_result=-8387747
# Discrepancy found: a=-16774842, b=-16775169, C_result=1981043223, Python_result=8387421
# Discrepancy found: a=-16774841, b=-16775169, C_result=1964268054, Python_result=-8387748
# Discrepancy found: a=-16774840, b=-16775169, C_result=1913942548, Python_result=8387420
# Discrepancy found: a=-16774839, b=-16775169, C_result=1897167379, Python_result=-8387749
# Discrepancy found: a=-16774838, b=-16775169, C_result=1846841873, Python_result=8387419
# Discrepancy found: a=-16774837, b=-16775169, C_result=1830066704, Python_result=-8387750
# Discrepancy found: a=-16774836, b=-16775169, C_result=1779741198, Python_result=8387418
# Discrepancy found: a=-16774835, b=-16775169, C_result=1762966029, Python_result=-8387751
# Discrepancy found: a=-16774834, b=-16775169, C_result=1712640523, Python_result=8387417
# Discrepancy found: a=-16774833, b=-16775169, C_result=1695865354, Python_result=-8387752
# Discrepancy found: a=-16774832, b=-16775169, C_result=1645539848, Python_result=8387416
# Discrepancy found: a=-16774831, b=-16775169, C_result=1628764679, Python_result=-8387753
# Discrepancy found: a=-16774830, b=-16775169, C_result=1578439173, Python_result=8387415
# Discrepancy found: a=-16774829, b=-16775169, C_result=1561664004, Python_result=-8387754
# Discrepancy found: a=-16774828, b=-16775169, C_result=1511338498, Python_result=8387414
# Discrepancy found: a=-16774827, b=-16775169, C_result=1494563329, Python_result=-8387755
# Discrepancy found: a=-16774826, b=-16775169, C_result=1444237823, Python_result=8387413
# Discrepancy found: a=-16774825, b=-16775169, C_result=1427462654, Python_result=-8387756
# Discrepancy found: a=-16774824, b=-16775169, C_result=1377137148, Python_result=8387412
# Discrepancy found: a=-16774823, b=-16775169, C_result=1360361979, Python_result=-8387757
# Discrepancy found: a=-16774822, b=-16775169, C_result=1310036473, Python_result=8387411
# Discrepancy found: a=-16774821, b=-16775169, C_result=1293261304, Python_result=-8387758
# Discrepancy found: a=-16774820, b=-16775169, C_result=1242935798, Python_result=8387410
# Discrepancy found: a=-16774819, b=-16775169, C_result=1226160629, Python_result=-8387759
# Discrepancy found: a=-16774818, b=-16775169, C_result=1175835123, Python_result=8387409
# Discrepancy found: a=-16774817, b=-16775169, C_result=1159059954, Python_result=-8387760
# Discrepancy found: a=-16774816, b=-16775169, C_result=1108734448, Python_result=8387408
# Discrepancy found: a=-16774815, b=-16775169, C_result=1091959279, Python_result=-8387761
# Discrepancy found: a=-16774814, b=-16775169, C_result=1041633773, Python_result=8387407
# Discrepancy found: a=-16774813, b=-16775169, C_result=1024858604, Python_result=-8387762
# Discrepancy found: a=-16774812, b=-16775169, C_result=974533098, Python_result=8387406
# Discrepancy found: a=-16774811, b=-16775169, C_result=957757929, Python_result=-8387763
# Discrepancy found: a=-16774810, b=-16775169, C_result=907432423, Python_result=8387405
# Discrepancy found: a=-16774809, b=-16775169, C_result=890657254, Python_result=-8387764
# Discrepancy found: a=-16774808, b=-16775169, C_result=840331748, Python_result=8387404
# Discrepancy found: a=-16774807, b=-16775169, C_result=823556579, Python_result=-8387765
# Discrepancy found: a=-16774806, b=-16775169, C_result=773231073, Python_result=8387403
# Discrepancy found: a=-16774805, b=-16775169, C_result=756455904, Python_result=-8387766
# Discrepancy found: a=-16774804, b=-16775169, C_result=706130398, Python_result=8387402
# Discrepancy found: a=-16774803, b=-16775169, C_result=689355229, Python_result=-8387767
# Discrepancy found: a=-16774802, b=-16775169, C_result=639029723, Python_result=8387401
# Discrepancy found: a=-16774801, b=-16775169, C_result=622254554, Python_result=-8387768
# Discrepancy found: a=-16774800, b=-16775169, C_result=571929048, Python_result=8387400
# Discrepancy found: a=-16774799, b=-16775169, C_result=555153879, Python_result=-8387769
# Discrepancy found: a=-16774798, b=-16775169, C_result=504828373, Python_result=8387399
# Discrepancy found: a=-16774797, b=-16775169, C_result=488053204, Python_result=-8387770
# Discrepancy found: a=-16774796, b=-16775169, C_result=437727698, Python_result=8387398
# Discrepancy found: a=-16774795, b=-16775169, C_result=420952529, Python_result=-8387771
# Discrepancy found: a=-16774794, b=-16775169, C_result=370627023, Python_result=8387397
# Discrepancy found: a=-16774793, b=-16775169, C_result=353851854, Python_result=-8387772
# Discrepancy found: a=-16774792, b=-16775169, C_result=303526348, Python_result=8387396
# Discrepancy found: a=-16774791, b=-16775169, C_result=286751179, Python_result=-8387773
# Discrepancy found: a=-16774790, b=-16775169, C_result=236425673, Python_result=8387395
# Discrepancy found: a=-16774789, b=-16775169, C_result=219650504, Python_result=-8387774
# Discrepancy found: a=-16774788, b=-16775169, C_result=169324998, Python_result=8387394
# Discrepancy found: a=-16774787, b=-16775169, C_result=152549829, Python_result=-8387775
# Discrepancy found: a=-16774786, b=-16775169, C_result=102224323, Python_result=8387393
# Discrepancy found: a=-16774785, b=-16775169, C_result=85449154, Python_result=-8387776
# Discrepancy found: a=-16774784, b=-16775169, C_result=35123648, Python_result=8387392
# Discrepancy found: a=-16774783, b=-16775169, C_result=18348479, Python_result=-8387777
# Discrepancy found: a=-16774782, b=-16775169, C_result=-31977027, Python_result=8387391
# Discrepancy found: a=-16774781, b=-16775169, C_result=-48752196, Python_result=-8387778
# Discrepancy found: a=-16774780, b=-16775169, C_result=-99077702, Python_result=8387390
# Discrepancy found: a=-16774779, b=-16775169, C_result=-115852871, Python_result=-8387779
# Discrepancy found: a=-16774778, b=-16775169, C_result=-166178377, Python_result=8387389
# Discrepancy found: a=-16774777, b=-16775169, C_result=-182953546, Python_result=-8387780
# Discrepancy found: a=-16774776, b=-16775169, C_result=-233279052, Python_result=8387388
# Discrepancy found: a=-16774775, b=-16775169, C_result=-250054221, Python_result=-8387781
# Discrepancy found: a=-16774774, b=-16775169, C_result=-300379727, Python_result=8387387
# Discrepancy found: a=-16774773, b=-16775169, C_result=-317154896, Python_result=-8387782
# Discrepancy found: a=-16774772, b=-16775169, C_result=-367480402, Python_result=8387386
# Discrepancy found: a=-16774771, b=-16775169, C_result=-384255571, Python_result=-8387783
# Discrepancy found: a=-16774770, b=-16775169, C_result=-434581077, Python_result=8387385
# Discrepancy found: a=-16774769, b=-16775169, C_result=-451356246, Python_result=-8387784
# Discrepancy found: a=-16774768, b=-16775169, C_result=-501681752, Python_result=8387384
# Discrepancy found: a=-16774767, b=-16775169, C_result=-518456921, Python_result=-8387785
# Discrepancy found: a=-16774766, b=-16775169, C_result=-568782427, Python_result=8387383
# Discrepancy found: a=-16774765, b=-16775169, C_result=-585557596, Python_result=-8387786
# Discrepancy found: a=-16774764, b=-16775169, C_result=-635883102, Python_result=8387382
# Discrepancy found: a=-16774763, b=-16775169, C_result=-652658271, Python_result=-8387787
# Discrepancy found: a=-16774762, b=-16775169, C_result=-702983777, Python_result=8387381
# Discrepancy found: a=-16774761, b=-16775169, C_result=-719758946, Python_result=-8387788
# Discrepancy found: a=-16774760, b=-16775169, C_result=-770084452, Python_result=8387380
# Discrepancy found: a=-16774759, b=-16775169, C_result=-786859621, Python_result=-8387789
# Discrepancy found: a=-16774758, b=-16775169, C_result=-837185127, Python_result=8387379
# Discrepancy found: a=-16774757, b=-16775169, C_result=-853960296, Python_result=-8387790
# Discrepancy found: a=-16774756, b=-16775169, C_result=-904285802, Python_result=8387378
# Discrepancy found: a=-16774755, b=-16775169, C_result=-921060971, Python_result=-8387791
# Discrepancy found: a=-16774754, b=-16775169, C_result=-971386477, Python_result=8387377
# Discrepancy found: a=-16774753, b=-16775169, C_result=-988161646, Python_result=-8387792
# Discrepancy found: a=-16774752, b=-16775169, C_result=-1038487152, Python_result=8387376
# Discrepancy found: a=-16774751, b=-16775169, C_result=-1055262321, Python_result=-8387793
# Discrepancy found: a=-16774750, b=-16775169, C_result=-1105587827, Python_result=8387375
# Discrepancy found: a=-16774749, b=-16775169, C_result=-1122362996, Python_result=-8387794
# Discrepancy found: a=-16774748, b=-16775169, C_result=-1172688502, Python_result=8387374
# Discrepancy found: a=-16774747, b=-16775169, C_result=-1189463671, Python_result=-8387795
# Discrepancy found: a=-16774746, b=-16775169, C_result=-1239789177, Python_result=8387373
# Discrepancy found: a=-16774745, b=-16775169, C_result=-1256564346, Python_result=-8387796
# Discrepancy found: a=-16774744, b=-16775169, C_result=-1306889852, Python_result=8387372
# Discrepancy found: a=-16774743, b=-16775169, C_result=-1323665021, Python_result=-8387797
# Discrepancy found: a=-16774742, b=-16775169, C_result=-1373990527, Python_result=8387371
# Discrepancy found: a=-16774741, b=-16775169, C_result=-1390765696, Python_result=-8387798
# Discrepancy found: a=-16774740, b=-16775169, C_result=-1441091202, Python_result=8387370
# Discrepancy found: a=-16774739, b=-16775169, C_result=-1457866371, Python_result=-8387799
# Discrepancy found: a=-16774738, b=-16775169, C_result=-1508191877, Python_result=8387369
# Discrepancy found: a=-16774737, b=-16775169, C_result=-1524967046, Python_result=-8387800
# Discrepancy found: a=-16774736, b=-16775169, C_result=-1575292552, Python_result=8387368
# Discrepancy found: a=-16774735, b=-16775169, C_result=-1592067721, Python_result=-8387801
# Discrepancy found: a=-16774734, b=-16775169, C_result=-1642393227, Python_result=8387367
# Discrepancy found: a=-16774733, b=-16775169, C_result=-1659168396, Python_result=-8387802
# Discrepancy found: a=-16774732, b=-16775169, C_result=-1709493902, Python_result=8387366
# Discrepancy found: a=-16774731, b=-16775169, C_result=-1726269071, Python_result=-8387803
# Discrepancy found: a=-16774730, b=-16775169, C_result=-1776594577, Python_result=8387365
# Discrepancy found: a=-16774729, b=-16775169, C_result=-1793369746, Python_result=-8387804
# Discrepancy found: a=-16774728, b=-16775169, C_result=-1843695252, Python_result=8387364
# Discrepancy found: a=-16774727, b=-16775169, C_result=-1860470421, Python_result=-8387805
# Discrepancy found: a=-16774726, b=-16775169, C_result=-1910795927, Python_result=8387363
# Discrepancy found: a=-16774725, b=-16775169, C_result=-1927571096, Python_result=-8387806
# Discrepancy found: a=-16774724, b=-16775169, C_result=-1977896602, Python_result=8387362
# Discrepancy found: a=-16774723, b=-16775169, C_result=-1994671771, Python_result=-8387807
# Discrepancy found: a=-16774722, b=-16775169, C_result=-2044997277, Python_result=8387361
# Discrepancy found: a=-16774721, b=-16775169, C_result=-2061772446, Python_result=-8387808
# Discrepancy found: a=-16774720, b=-16775169, C_result=-2112097952, Python_result=8387360
# Discrepancy found: a=-16774719, b=-16775169, C_result=-2128873121, Python_result=-8387809
# Discrepancy found: a=-16774718, b=-16775169, C_result=2115768669, Python_result=8387359
# Discrepancy found: a=-16774717, b=-16775169, C_result=2098993500, Python_result=-8387810
# Discrepancy found: a=-16774716, b=-16775169, C_result=2048667994, Python_result=8387358
# Discrepancy found: a=-16774715, b=-16775169, C_result=2031892825, Python_result=-8387811
# Discrepancy found: a=-16774714, b=-16775169, C_result=1981567319, Python_result=8387357
# Discrepancy found: a=-16774713, b=-16775169, C_result=1964792150, Python_result=-8387812
# Discrepancy found: a=-16774712, b=-16775169, C_result=1914466644, Python_result=8387356
# Discrepancy found: a=-16774711, b=-16775169, C_result=1897691475, Python_result=-8387813
# Discrepancy found: a=-16774710, b=-16775169, C_result=1847365969, Python_result=8387355
# Discrepancy found: a=-16774709, b=-16775169, C_result=1830590800, Python_result=-8387814
# Discrepancy found: a=-16774708, b=-16775169, C_result=1780265294, Python_result=8387354
# Discrepancy found: a=-16774707, b=-16775169, C_result=1763490125, Python_result=-8387815
# Discrepancy found: a=-16774706, b=-16775169, C_result=1713164619, Python_result=8387353
# Discrepancy found: a=-16774705, b=-16775169, C_result=1696389450, Python_result=-8387816
# Discrepancy found: a=-16774704, b=-16775169, C_result=1646063944, Python_result=8387352
# Discrepancy found: a=-16774703, b=-16775169, C_result=1629288775, Python_result=-8387817
# Discrepancy found: a=-16774702, b=-16775169, C_result=1578963269, Python_result=8387351
# Discrepancy found: a=-16774701, b=-16775169, C_result=1562188100, Python_result=-8387818
# Discrepancy found: a=-16774700, b=-16775169, C_result=1511862594, Python_result=8387350
# Discrepancy found: a=-16774699, b=-16775169, C_result=1495087425, Python_result=-8387819
# Discrepancy found: a=-16774698, b=-16775169, C_result=1444761919, Python_result=8387349
# Discrepancy found: a=-16774697, b=-16775169, C_result=1427986750, Python_result=-8387820
# Discrepancy found: a=-16774696, b=-16775169, C_result=1377661244, Python_result=8387348
# Discrepancy found: a=-16774695, b=-16775169, C_result=1360886075, Python_result=-8387821
# Discrepancy found: a=-16774694, b=-16775169, C_result=1310560569, Python_result=8387347
# Discrepancy found: a=-16774693, b=-16775169, C_result=1293785400, Python_result=-8387822
# Discrepancy found: a=-16774692, b=-16775169, C_result=1243459894, Python_result=8387346
# Discrepancy found: a=-16774691, b=-16775169, C_result=1226684725, Python_result=-8387823
# Discrepancy found: a=-16774690, b=-16775169, C_result=1176359219, Python_result=8387345
# Discrepancy found: a=-16774689, b=-16775169, C_result=1159584050, Python_result=-8387824
# Discrepancy found: a=-16774688, b=-16775169, C_result=1109258544, Python_result=8387344
# Discrepancy found: a=-16774687, b=-16775169, C_result=1092483375, Python_result=-8387825
# Discrepancy found: a=-16774686, b=-16775169, C_result=1042157869, Python_result=8387343
# Discrepancy found: a=-16774685, b=-16775169, C_result=1025382700, Python_result=-8387826
# Discrepancy found: a=-16774684, b=-16775169, C_result=975057194, Python_result=8387342
# Discrepancy found: a=-16774683, b=-16775169, C_result=958282025, Python_result=-8387827
# Discrepancy found: a=-16774682, b=-16775169, C_result=907956519, Python_result=8387341
# Discrepancy found: a=-16774681, b=-16775169, C_result=891181350, Python_result=-8387828
# Discrepancy found: a=-16774680, b=-16775169, C_result=840855844, Python_result=8387340
# Discrepancy found: a=-16774679, b=-16775169, C_result=824080675, Python_result=-8387829
# Discrepancy found: a=-16774678, b=-16775169, C_result=773755169, Python_result=8387339
# Discrepancy found: a=-16774677, b=-16775169, C_result=756980000, Python_result=-8387830
# Discrepancy found: a=-16774676, b=-16775169, C_result=706654494, Python_result=8387338
# Discrepancy found: a=-16774675, b=-16775169, C_result=689879325, Python_result=-8387831
# Discrepancy found: a=-16774674, b=-16775169, C_result=639553819, Python_result=8387337
# Discrepancy found: a=-16774673, b=-16775169, C_result=622778650, Python_result=-8387832
# Discrepancy found: a=-16774672, b=-16775169, C_result=572453144, Python_result=8387336
# Discrepancy found: a=-16774671, b=-16775169, C_result=555677975, Python_result=-8387833
# Discrepancy found: a=-16774670, b=-16775169, C_result=505352469, Python_result=8387335
# Discrepancy found: a=-16774669, b=-16775169, C_result=488577300, Python_result=-8387834
# Discrepancy found: a=-16774668, b=-16775169, C_result=438251794, Python_result=8387334
# Discrepancy found: a=-16774667, b=-16775169, C_result=421476625, Python_result=-8387835
# Discrepancy found: a=-16774666, b=-16775169, C_result=371151119, Python_result=8387333
# Discrepancy found: a=-16774665, b=-16775169, C_result=354375950, Python_result=-8387836
# Discrepancy found: a=-16774664, b=-16775169, C_result=304050444, Python_result=8387332
# Discrepancy found: a=-16774663, b=-16775169, C_result=287275275, Python_result=-8387837
# Discrepancy found: a=-16774662, b=-16775169, C_result=236949769, Python_result=8387331
# Discrepancy found: a=-16774661, b=-16775169, C_result=220174600, Python_result=-8387838
# Discrepancy found: a=-16774660, b=-16775169, C_result=169849094, Python_result=8387330
# Discrepancy found: a=-16774659, b=-16775169, C_result=153073925, Python_result=-8387839
# Discrepancy found: a=-16774658, b=-16775169, C_result=102748419, Python_result=8387329
# Discrepancy found: a=-16774657, b=-16775169, C_result=85973250, Python_result=-8387840
# Discrepancy found: a=-16774656, b=-16775169, C_result=35647744, Python_result=8387328
# Discrepancy found: a=-16774655, b=-16775169, C_result=18872575, Python_result=-8387841
# Discrepancy found: a=-16774654, b=-16775169, C_result=-31452931, Python_result=8387327
# Discrepancy found: a=-16774653, b=-16775169, C_result=-48228100, Python_result=-8387842
# Discrepancy found: a=-16774652, b=-16775169, C_result=-98553606, Python_result=8387326
# Discrepancy found: a=-16774651, b=-16775169, C_result=-115328775, Python_result=-8387843
# Discrepancy found: a=-16774650, b=-16775169, C_result=-165654281, Python_result=8387325
# Discrepancy found: a=-16774649, b=-16775169, C_result=-182429450, Python_result=-8387844
# Discrepancy found: a=-16774648, b=-16775169, C_result=-232754956, Python_result=8387324
# Discrepancy found: a=-16774647, b=-16775169, C_result=-249530125, Python_result=-8387845
# Discrepancy found: a=-16774646, b=-16775169, C_result=-299855631, Python_result=8387323
# Discrepancy found: a=-16774645, b=-16775169, C_result=-316630800, Python_result=-8387846
# Discrepancy found: a=-16774644, b=-16775169, C_result=-366956306, Python_result=8387322
# Discrepancy found: a=-16774643, b=-16775169, C_result=-383731475, Python_result=-8387847
# Discrepancy found: a=-16774642, b=-16775169, C_result=-434056981, Python_result=8387321
# Discrepancy found: a=-16774641, b=-16775169, C_result=-450832150, Python_result=-8387848
# Discrepancy found: a=-16774640, b=-16775169, C_result=-501157656, Python_result=8387320
# Discrepancy found: a=-16774639, b=-16775169, C_result=-517932825, Python_result=-8387849
# Discrepancy found: a=-16774638, b=-16775169, C_result=-568258331, Python_result=8387319
# Discrepancy found: a=-16774637, b=-16775169, C_result=-585033500, Python_result=-8387850
# Discrepancy found: a=-16774636, b=-16775169, C_result=-635359006, Python_result=8387318
# Discrepancy found: a=-16774635, b=-16775169, C_result=-652134175, Python_result=-8387851
# Discrepancy found: a=-16774634, b=-16775169, C_result=-702459681, Python_result=8387317
# Discrepancy found: a=-16774633, b=-16775169, C_result=-719234850, Python_result=-8387852
# Discrepancy found: a=-16774632, b=-16775169, C_result=-769560356, Python_result=8387316
# Discrepancy found: a=-16774631, b=-16775169, C_result=-786335525, Python_result=-8387853
# Discrepancy found: a=-16774630, b=-16775169, C_result=-836661031, Python_result=8387315
# Discrepancy found: a=-16774629, b=-16775169, C_result=-853436200, Python_result=-8387854
# Discrepancy found: a=-16774628, b=-16775169, C_result=-903761706, Python_result=8387314
# ...
# Discrepancy found: a=-16755866, b=-16775169, C_result=984998631, Python_result=8377933
# Discrepancy found: a=-16755865, b=-16775169, C_result=968223462, Python_result=-8397236
# Discrepancy found: a=-16755864, b=-16775169, C_result=917897956, Python_result=8377932
# Discrepancy found: a=-16755863, b=-16775169, C_result=901122787, Python_result=-8397237
# Discrepancy found: a=-16755862, b=-16775169, C_result=850797281, Python_result=8377931
# Discrepancy found: a=-16755861, b=-16775169, C_result=834022112, Python_result=-8397238
# Discrepancy found: a=-16755860, b=-16775169, C_result=783696606, Python_result=8377930
# Discrepancy found: a=-16755859, b=-16775169, C_result=766921437, Python_result=-8397239
# Discrepancy found: a=-16755858, b=-16775169, C_result=716595931, Python_result=8377929
# Discrepancy found: a=-16755857, b=-16775169, C_result=699820762, Python_result=-8397240
# Discrepancy found: a=-16755856, b=-16775169, C_result=649495256, Python_result=8377928
# Discrepancy found: a=-16755855, b=-16775169, C_result=632720087, Python_result=-8397241
# Discrepancy found: a=-16755854, b=-16775169, C_result=582394581, Python_result=8377927
# Discrepancy found: a=-16755853, b=-16775169, C_result=565619412, Python_result=-8397242
# Discrepancy found: a=-16755852, b=-16775169, C_result=515293906, Python_result=8377926
# Discrepancy found: a=-16755851, b=-16775169, C_result=498518737, Python_result=-8397243
# Discrepancy found: a=-16755850, b=-16775169, C_result=448193231, Python_result=8377925
# Discrepancy found: a=-16755849, b=-16775169, C_result=431418062, Python_result=-8397244
# Discrepancy found: a=-16755848, b=-16775169, C_result=381092556, Python_result=8377924
# Discrepancy found: a=-16755847, b=-16775169, C_result=364317387, Python_result=-8397245
# Discrepancy found: a=-16755846, b=-16775169, C_result=313991881, Python_result=8377923
# Discrepancy found: a=-16755845, b=-16775169, C_result=297216712, Python_result=-8397246
# Discrepancy found: a=-16755844, b=-16775169, C_result=246891206, Python_result=8377922
# Discrepancy found: a=-16755843, b=-16775169, C_result=230116037, Python_result=-8397247
# Discrepancy found: a=-16755842, b=-16775169, C_result=179790531, Python_result=8377921
# Discrepancy found: a=-16755841, b=-16775169, C_result=163015362, Python_result=-8397248
# Discrepancy found: a=-16755840, b=-16775169, C_result=112689856, Python_result=8377920
# Discrepancy found: a=-16755839, b=-16775169, C_result=95914687, Python_result=-8397249
# Discrepancy found: a=-16755838, b=-16775169, C_result=45589181, Python_result=8377919
# Discrepancy found: a=-16755837, b=-16775169, C_result=28814012, Python_result=-8397250
# Discrepancy found: a=-16755836, b=-16775169, C_result=-21511494, Python_result=8377918
# Discrepancy found: a=-16755835, b=-16775169, C_result=-38286663, Python_result=-8397251
# Discrepancy found: a=-16755834, b=-16775169, C_result=-88612169, Python_result=8377917
# Discrepancy found: a=-16755833, b=-16775169, C_result=-105387338, Python_result=-8397252
# Discrepancy found: a=-16755832, b=-16775169, C_result=-155712844, Python_result=8377916
# Discrepancy found: a=-16755831, b=-16775169, C_result=-172488013, Python_result=-8397253
# Discrepancy found: a=-16755830, b=-16775169, C_result=-222813519, Python_result=8377915
# Discrepancy found: a=-16755829, b=-16775169, C_result=-239588688, Python_result=-8397254
# Discrepancy found: a=-16755828, b=-16775169, C_result=-289914194, Python_result=8377914
# Discrepancy found: a=-16755827, b=-16775169, C_result=-306689363, Python_result=-8397255
# Discrepancy found: a=-16755826, b=-16775169, C_result=-357014869, Python_result=8377913
# Discrepancy found: a=-16755825, b=-16775169, C_result=-373790038, Python_result=-8397256
# Discrepancy found: a=-16755824, b=-16775169, C_result=-424115544, Python_result=8377912
# Discrepancy found: a=-16755823, b=-16775169, C_result=-440890713, Python_result=-8397257
# Discrepancy found: a=-16755822, b=-16775169, C_result=-491216219, Python_result=8377911
# Discrepancy found: a=-16755821, b=-16775169, C_result=-507991388, Python_result=-8397258
# Discrepancy found: a=-16755820, b=-16775169, C_result=-558316894, Python_result=8377910
# Discrepancy found: a=-16755819, b=-16775169, C_result=-575092063, Python_result=-8397259
# Discrepancy found: a=-16755818, b=-16775169, C_result=-625417569, Python_result=8377909
# Discrepancy found: a=-16755817, b=-16775169, C_result=-642192738, Python_result=-8397260
# Discrepancy found: a=-16755816, b=-16775169, C_result=-692518244, Python_result=8377908
# Discrepancy found: a=-16755815, b=-16775169, C_result=-709293413, Python_result=-8397261
# Discrepancy found: a=-16755814, b=-16775169, C_result=-759618919, Python_result=8377907
# Discrepancy found: a=-16755813, b=-16775169, C_result=-776394088, Python_result=-8397262
# Discrepancy found: a=-16755812, b=-16775169, C_result=-826719594, Python_result=8377906
# Discrepancy found: a=-16755811, b=-16775169, C_result=-843494763, Python_result=-8397263
# Discrepancy found: a=-16755810, b=-16775169, C_result=-893820269, Python_result=8377905
# Discrepancy found: a=-16755809, b=-16775169, C_result=-910595438, Python_result=-8397264
# Discrepancy found: a=-16755808, b=-16775169, C_result=-960920944, Python_result=8377904
# Discrepancy found: a=-16755807, b=-16775169, C_result=-977696113, Python_result=-8397265
# Discrepancy found: a=-16755806, b=-16775169, C_result=-1028021619, Python_result=8377903
# Discrepancy found: a=-16755805, b=-16775169, C_result=-1044796788, Python_result=-8397266
# Discrepancy found: a=-16755804, b=-16775169, C_result=-1095122294, Python_result=8377902
# Discrepancy found: a=-16755803, b=-16775169, C_result=-1111897463, Python_result=-8397267
# Discrepancy found: a=-16755802, b=-16775169, C_result=-1162222969, Python_result=8377901
# Discrepancy found: a=-16755801, b=-16775169, C_result=-1178998138, Python_result=-8397268
# Discrepancy found: a=-16755800, b=-16775169, C_result=-1229323644, Python_result=8377900
# Discrepancy found: a=-16755799, b=-16775169, C_result=-1246098813, Python_result=-8397269
# Discrepancy found: a=-16755798, b=-16775169, C_result=-1296424319, Python_result=8377899
# Discrepancy found: a=-16755797, b=-16775169, C_result=-1313199488, Python_result=-8397270
# Discrepancy found: a=-16755796, b=-16775169, C_result=-1363524994, Python_result=8377898
# Discrepancy found: a=-16755795, b=-16775169, C_result=-1380300163, Python_result=-8397271
# Discrepancy found: a=-16755794, b=-16775169, C_result=-1430625669, Python_result=8377897
# Discrepancy found: a=-16755793, b=-16775169, C_result=-1447400838, Python_result=-8397272
# Discrepancy found: a=-16755792, b=-16775169, C_result=-1497726344, Python_result=8377896
# Discrepancy found: a=-16755791, b=-16775169, C_result=-1514501513, Python_result=-8397273
# Discrepancy found: a=-16755790, b=-16775169, C_result=-1564827019, Python_result=8377895
# Discrepancy found: a=-16755789, b=-16775169, C_result=-1581602188, Python_result=-8397274
# Discrepancy found: a=-16755788, b=-16775169, C_result=-1631927694, Python_result=8377894
# Discrepancy found: a=-16755787, b=-16775169, C_result=-1648702863, Python_result=-8397275
# Discrepancy found: a=-16755786, b=-16775169, C_result=-1699028369, Python_result=8377893
# Discrepancy found: a=-16755785, b=-16775169, C_result=-1715803538, Python_result=-8397276
# Discrepancy found: a=-16755784, b=-16775169, C_result=-1766129044, Python_result=8377892
# Discrepancy found: a=-16755783, b=-16775169, C_result=-1782904213, Python_result=-8397277
# Discrepancy found: a=-16755782, b=-16775169, C_result=-1833229719, Python_result=8377891
# Discrepancy found: a=-16755781, b=-16775169, C_result=-1850004888, Python_result=-8397278
# Discrepancy found: a=-16755780, b=-16775169, C_result=-1900330394, Python_result=8377890
# Discrepancy found: a=-16755779, b=-16775169, C_result=-1917105563, Python_result=-8397279
# Discrepancy found: a=-16755778, b=-16775169, C_result=-1967431069, Python_result=8377889
# Discrepancy found: a=-16755777, b=-16775169, C_result=-1984206238, Python_result=-8397280
# Discrepancy found: a=-16755776, b=-16775169, C_result=-2034531744, Python_result=8377888
# Discrepancy found: a=-16755775, b=-16775169, C_result=-2051306913, Python_result=-8397281
# Discrepancy found: a=-16755774, b=-16775169, C_result=-2101632419, Python_result=8377887
# Discrepancy found: a=-16755773, b=-16775169, C_result=-2118407588, Python_result=-8397282
# Discrepancy found: a=-16755772, b=-16775169, C_result=2126234202, Python_result=8377886
# Discrepancy found: a=-16755771, b=-16775169, C_result=2109459033, Python_result=-8397283
# Discrepancy found: a=-16755770, b=-16775169, C_result=2059133527, Python_result=8377885
# Discrepancy found: a=-16755769, b=-16775169, C_result=2042358358, Python_result=-8397284
# Discrepancy found: a=-16755768, b=-16775169, C_result=1992032852, Python_result=8377884
# Discrepancy found: a=-16755767, b=-16775169, C_result=1975257683, Python_result=-8397285
# Discrepancy found: a=-16755766, b=-16775169, C_result=1924932177, Python_result=8377883
# Discrepancy found: a=-16755765, b=-16775169, C_result=1908157008, Python_result=-8397286
# Discrepancy found: a=-16755764, b=-16775169, C_result=1857831502, Python_result=8377882
# Discrepancy found: a=-16755763, b=-16775169, C_result=1841056333, Python_result=-8397287
# Discrepancy found: a=-16755762, b=-16775169, C_result=1790730827, Python_result=8377881
# Discrepancy found: a=-16755761, b=-16775169, C_result=1773955658, Python_result=-8397288
# Discrepancy found: a=-16755760, b=-16775169, C_result=1723630152, Python_result=8377880
# Discrepancy found: a=-16755759, b=-16775169, C_result=1706854983, Python_result=-8397289
# Discrepancy found: a=-16755758, b=-16775169, C_result=1656529477, Python_result=8377879
# Discrepancy found: a=-16755757, b=-16775169, C_result=1639754308, Python_result=-8397290
# Discrepancy found: a=-16755756, b=-16775169, C_result=1589428802, Python_result=8377878
# Discrepancy found: a=-16755755, b=-16775169, C_result=1572653633, Python_result=-8397291
# Discrepancy found: a=-16755754, b=-16775169, C_result=1522328127, Python_result=8377877
# Discrepancy found: a=-16755753, b=-16775169, C_result=1505552958, Python_result=-8397292
# Discrepancy found: a=-16755752, b=-16775169, C_result=1455227452, Python_result=8377876
# Discrepancy found: a=-16755751, b=-16775169, C_result=1438452283, Python_result=-8397293
# Discrepancy found: a=-16755750, b=-16775169, C_result=1388126777, Python_result=8377875
# Discrepancy found: a=-16755749, b=-16775169, C_result=1371351608, Python_result=-8397294
# Discrepancy found: a=-16755748, b=-16775169, C_result=1321026102, Python_result=8377874
# Discrepancy found: a=-16755747, b=-16775169, C_result=1304250933, Python_result=-8397295
# Discrepancy found: a=-16755746, b=-16775169, C_result=1253925427, Python_result=8377873
# Discrepancy found: a=-16755745, b=-16775169, C_result=1237150258, Python_result=-8397296
# Discrepancy found: a=-16755744, b=-16775169, C_result=1186824752, Python_result=8377872
# Discrepancy found: a=-16755743, b=-16775169, C_result=1170049583, Python_result=-8397297
# Discrepancy found: a=-16755742, b=-16775169, C_result=1119724077, Python_result=8377871
# Discrepancy found: a=-16755741, b=-16775169, C_result=1102948908, Python_result=-8397298
# Discrepancy found: a=-16755740, b=-16775169, C_result=1052623402, Python_result=8377870
# Discrepancy found: a=-16755739, b=-16775169, C_result=1035848233, Python_result=-8397299
# Discrepancy found: a=-16755738, b=-16775169, C_result=985522727, Python_result=8377869
# Discrepancy found: a=-16755737, b=-16775169, C_result=968747558, Python_result=-8397300
# Discrepancy found: a=-16755736, b=-16775169, C_result=918422052, Python_result=8377868
# Discrepancy found: a=-16755735, b=-16775169, C_result=901646883, Python_result=-8397301
# Discrepancy found: a=-16755734, b=-16775169, C_result=851321377, Python_result=8377867
# Discrepancy found: a=-16755733, b=-16775169, C_result=834546208, Python_result=-8397302
# Discrepancy found: a=-16755732, b=-16775169, C_result=784220702, Python_result=8377866
# Discrepancy found: a=-16755731, b=-16775169, C_result=767445533, Python_result=-8397303
# Discrepancy found: a=-16755730, b=-16775169, C_result=717120027, Python_result=8377865
# Discrepancy found: a=-16755729, b=-16775169, C_result=700344858, Python_result=-8397304
# Discrepancy found: a=-16755728, b=-16775169, C_result=650019352, Python_result=8377864
# Discrepancy found: a=-16755727, b=-16775169, C_result=633244183, Python_result=-8397305
# Discrepancy found: a=-16755726, b=-16775169, C_result=582918677, Python_result=8377863
# Discrepancy found: a=-16755725, b=-16775169, C_result=566143508, Python_result=-8397306
# Discrepancy found: a=-16755724, b=-16775169, C_result=515818002, Python_result=8377862
# Discrepancy found: a=-16755723, b=-16775169, C_result=499042833, Python_result=-8397307
# Discrepancy found: a=-16755722, b=-16775169, C_result=448717327, Python_result=8377861
# Discrepancy found: a=-16755721, b=-16775169, C_result=431942158, Python_result=-8397308
# Discrepancy found: a=-16755720, b=-16775169, C_result=381616652, Python_result=8377860
# Discrepancy found: a=-16755719, b=-16775169, C_result=364841483, Python_result=-8397309
# Discrepancy found: a=-16755718, b=-16775169, C_result=314515977, Python_result=8377859
# Discrepancy found: a=-16755717, b=-16775169, C_result=297740808, Python_result=-8397310
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 17
#      14 # 遍歷 a
#      15 for a in range(-p // 2, p // 2 + 1):
#      16     # 執行 C 程式
# ---> 17     process = subprocess.run(
#      18         ["./Barrett_mul", str(a), str(b), str(p), str(mu_b)],
#      19         capture_output=True,
#      20         text=True
#      21     )
#      23     # 確保執行成功
#      24     if process.returncode != 0:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.14_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     500     kwargs['stdout'] = PIPE
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#     505         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.14_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/homebrew/Cellar/python@3.10/3.10.14_1/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1819, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1817 errpipe_data = bytearray()
#    1818 while True:
# -> 1819     part = os.read(errpipe_read, 50000)
#    1820     errpipe_data += part
#    1821     if not part or len(errpipe_data) > 50000:
#
# KeyboardInterrupt:
